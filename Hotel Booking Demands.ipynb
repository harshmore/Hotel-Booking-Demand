# %% [markdown]
# # Importing Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # Loading Dataset

# %%
data = pd.read_csv("hotel_bookings.csv")
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# datatype info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Statistical info
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
data.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data.children.unique()
# Out:
# array([ 0.,  1.,  2., 10.,  3., nan])

# %%
data.babies.unique()
# Out:
# array([ 0,  1,  2, 10,  9], dtype=int64)

# %%
data.adults.unique()
# Out:
# array([ 2,  1,  3,  4, 40, 26, 50, 27, 55,  0, 20,  6,  5, 10],
#       dtype=int64)

# %%
# Missing Values Handling
data.fillna(value={"children":0,'agent':0,'company':0},inplace = True)

# %%
data.isna().sum()
# Out:
# hotel                               0
# is_canceled                         0
# lead_time                           0
# arrival_date_year                   0
# arrival_date_month                  0
# arrival_date_week_number            0
# arrival_date_day_of_month           0
# stays_in_weekend_nights             0
# stays_in_week_nights                0
# adults                              0
# children                            0
# babies                              0
# meal                                0
# country                           488
# market_segment                      0
# distribution_channel                0
# is_repeated_guest                   0
# previous_cancellations              0
# previous_bookings_not_canceled      0
# reserved_room_type                  0
# assigned_room_type                  0
# booking_changes                     0
# deposit_type                        0
# agent                               0
# company                             0
# ...

# %%
pd.set_option('display.max_columns',32)

# %%
data = data.loc[~((data.adults==0) & (data.children==0) & (data.babies==0))]

# %%
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (118732, 32)

# %%
data.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# # Coorelation Matrix

# %%
numerical_columns = [col for col in data.columns if data.dtypes[col] !='object']

# %%
numerical_columns
# Out:
# ['is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'booking_changes',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests']

# %%
corr = data[numerical_columns].corr()
plt.figure(figsize=(15,8))
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %%
corr['is_canceled']
# Out:
# is_canceled                       1.000000
# lead_time                         0.291548
# arrival_date_year                 0.016335
# arrival_date_week_number          0.007681
# arrival_date_day_of_month        -0.006048
# stays_in_weekend_nights          -0.002230
# stays_in_week_nights              0.024796
# adults                            0.056157
# children                          0.004523
# babies                           -0.032608
# is_repeated_guest                -0.084146
# previous_cancellations            0.109902
# previous_bookings_not_canceled   -0.055504
# booking_changes                  -0.145147
# agent                            -0.046885
# company                          -0.082211
# days_in_waiting_list              0.054105
# adr                               0.044819
# required_car_parking_spaces      -0.195018
# total_of_special_requests        -0.235874
# Name: is_canceled, dtype: float64

# %%
corr["is_canceled"].sort_values(ascending = False)
# Out:
# is_canceled                       1.000000
# lead_time                         0.291548
# previous_cancellations            0.109902
# adults                            0.056157
# days_in_waiting_list              0.054105
# adr                               0.044819
# stays_in_week_nights              0.024796
# arrival_date_year                 0.016335
# arrival_date_week_number          0.007681
# children                          0.004523
# stays_in_weekend_nights          -0.002230
# arrival_date_day_of_month        -0.006048
# babies                           -0.032608
# agent                            -0.046885
# previous_bookings_not_canceled   -0.055504
# company                          -0.082211
# is_repeated_guest                -0.084146
# booking_changes                  -0.145147
# required_car_parking_spaces      -0.195018
# total_of_special_requests        -0.235874
# Name: is_canceled, dtype: float64

# %%
corr["is_canceled"].sort_values()
# Out:
# total_of_special_requests        -0.235874
# required_car_parking_spaces      -0.195018
# booking_changes                  -0.145147
# is_repeated_guest                -0.084146
# company                          -0.082211
# previous_bookings_not_canceled   -0.055504
# agent                            -0.046885
# babies                           -0.032608
# arrival_date_day_of_month        -0.006048
# stays_in_weekend_nights          -0.002230
# children                          0.004523
# arrival_date_week_number          0.007681
# arrival_date_year                 0.016335
# stays_in_week_nights              0.024796
# adr                               0.044819
# days_in_waiting_list              0.054105
# adults                            0.056157
# previous_cancellations            0.109902
# lead_time                         0.291548
# is_canceled                       1.000000
# Name: is_canceled, dtype: float64

# %%
data.reservation_status_date = pd.to_datetime(data.reservation_status_date)

# %%
categorical_columns = [col for col in data.columns if data.dtypes[col] =='object']

# %%
categorical_columns
# Out:
# ['hotel',
#  'arrival_date_month',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'reserved_room_type',
#  'assigned_room_type',
#  'deposit_type',
#  'customer_type',
#  'reservation_status']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in categorical_columns:
    data[col] = le.fit_transform(data[col])
data[categorical_columns].head()
# Out:
#    hotel  arrival_date_month  meal  country  market_segment  \
# 0      1                   5     0      135               3
# 1      1                   5     0      135               3
# 2      1                   5     0       59               3
# 3      1                   5     0       59               2
# 4      1                   5     0       59               6
#
#    distribution_channel  reserved_room_type  assigned_room_type  deposit_type  \
# 0                     1                   2                   2             0
# 1                     1                   2                   2             0
# 2                     1                   0                   2             0
# 3                     0                   0                   0             0
# 4                     3                   0                   0             0
#
#    customer_type  reservation_status
# 0              2                   1
# 1              2                   1
# ...

# %%
categorical_columns.append('is_canceled')

# %%
cat_corr = data[categorical_columns].corr()
plt.figure(figsize=(15,8))
sns.heatmap(cat_corr,annot=True,cmap='coolwarm')
plt.show()

# %%
cat_corr['is_canceled']
# Out:
# hotel                  -0.134556
# arrival_date_month     -0.001664
# meal                   -0.017972
# country                 0.270894
# market_segment          0.056759
# distribution_channel    0.165411
# reserved_room_type     -0.062586
# assigned_room_type     -0.174910
# deposit_type            0.468430
# customer_type          -0.068804
# reservation_status     -0.917220
# is_canceled             1.000000
# Name: is_canceled, dtype: float64

# %%
cat_corr['is_canceled'].sort_values()
# Out:
# reservation_status     -0.917220
# assigned_room_type     -0.174910
# hotel                  -0.134556
# customer_type          -0.068804
# reserved_room_type     -0.062586
# meal                   -0.017972
# arrival_date_month     -0.001664
# market_segment          0.056759
# distribution_channel    0.165411
# country                 0.270894
# deposit_type            0.468430
# is_canceled             1.000000
# Name: is_canceled, dtype: float64

# %%
cat_corr['is_canceled'].sort_values(ascending = False)
# Out:
# is_canceled             1.000000
# deposit_type            0.468430
# country                 0.270894
# distribution_channel    0.165411
# market_segment          0.056759
# arrival_date_month     -0.001664
# meal                   -0.017972
# reserved_room_type     -0.062586
# customer_type          -0.068804
# hotel                  -0.134556
# assigned_room_type     -0.174910
# reservation_status     -0.917220
# Name: is_canceled, dtype: float64

# %% [markdown]
# # Input Split

# %%
X = data.drop(columns = ["arrival_date_year", "arrival_date_week_number", "is_canceled", 'company', "arrival_date_month", 'reserved_room_type',"customer_type",'reservation_status_date'])
y = data["is_canceled"]

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import  train_test_split,cross_val_score

def train(model, X, y) :
    # train test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify = y)


    # model fitting
    model[1].fit(X_train, y_train)

    # cross validation
    cv_score = cross_val_score(model[1], X, y, cv=5)
    
    print(model[0])
    print("Accuracy:", model[1].score(X_test,y_test))
    print("CV Score:", np.mean(cv_score))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

models = [('LogisticRegression',LogisticRegression()),
         ('KNN',KNeighborsClassifier(n_neighbors=5)),
         ('DecisionTree',DecisionTreeClassifier()),
         ('RandomForest',RandomForestClassifier())]

for model in models:
    train(model,X,y)
    print()
# Out:
# LogisticRegression
# Accuracy: 0.985906793935991
# CV Score: 0.9807128716168009
#
# KNN
# Accuracy: 0.7966872543514879
# CV Score: 0.636408038115351
#
# DecisionTree
# Accuracy: 1.0
# CV Score: 1.0
#
# RandomForest
# Accuracy: 1.0
# CV Score: 0.9999578894176107
